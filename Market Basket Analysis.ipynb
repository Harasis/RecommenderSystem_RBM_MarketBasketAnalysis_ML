# %% [markdown]
# to uncover association amoung different items when customer is buying, Market Basket Analysis is used
# Used for the purpose of cross-selling
# The algorithm used behind MBA is __APRIORI__
#
# ]#pip install apyori
#
# Apriori Algo uses frequent item sets to generate association rules
# --Based on a concept that a subset of a frequent item-set must be a frequent item-set
#
# Say, a transaction containing {Grapes, Apple, Mango} also contains {Grapes, Mango}. So, according to the principle of Apriori, if {Grapes, Apple, Mango} is frequent, then {Grapes, Mango} must also be frequent.
#
#
# Apriori Algo generate association rules-
#
# - Support = Default Popularity of an item.
#
#            - Support= frequency(itemA)/N
#
# - Confidence = Likelihood that customer who bought both A and B.
#
#            - Confidence = freq(item A, item B)/freq(item A)
#
# - Lift = Increase in the sale of A when you sell B.
#
#            - Lift = Confidence(A,B)/Support(B)

# %% [markdown]
# - Lift (A => B) = 1 means that there is no correlation within the itemset.
#
# - Lift (A => B) > 1 means that there is a positive correlation within the itemset, i.e., products in the itemset, A, and B, are more likely to be bought together.
#
# - Lift (A => B) < 1 means that there is a negative correlation within the itemset, i.e., products in itemset, A, and B, are unlikely to be bought together.

# %%
import pandas as pd

# %%
df = pd.read_csv("Market_Basket_Optimisation.csv", header = None)

# %%
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
df.loc[1]
# Out:
# 0       burgers
# 1     meatballs
# 2          eggs
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# Name: 1, dtype: object

# %%
type(df)

#Apriori Support Numpy type We have to convert
# Out:
# pandas.core.frame.DataFrame

# %%
from apyori import apriori

# %% [raw]
# We have to convert Dataset into 2D array using the Loop
#
# df.values -- convert df into numpy array
#
# df.loc[] -- to retrieve values

# %%
len(df)
# Out:
# 7501

# %%
#Converting df to 2D array and saving it in empty list transations


transactions = []
for i in range(0, len(df)):
    transactions.append([  str(df.values[i,j])
                         for j in range(0,len(df.loc[i]))])

# %%
transactions[0]
# Out:
# ['shrimp',
#  'almonds',
#  'avocado',
#  'vegetables mix',
#  'green grapes',
#  'whole weat flour',
#  'yams',
#  'cottage cheese',
#  'energy drink',
#  'tomato juice',
#  'low fat yogurt',
#  'green tea',
#  'honey',
#  'salad',
#  'mineral water',
#  'salmon',
#  'antioxydant juice',
#  'frozen smoothie',
#  'spinach',
#  'olive oil']

# %%
rules = apriori(transactions = transactions, 
                min_support=0.003, 
                min_confidence=0.2,
                min_lift=3,
                min_length=3,
                max_length=3
               )

#Executes Apriori algorithm and returns a RelationRecord generator.

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'mushroom cream sauce', 'escalope'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'pasta', 'escalope'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
# ...

# %% [raw]
# RelationRecord(items=frozenset({'chicken', 'light cream'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)])
#
# (items_base=frozenset({'light cream'}) = ie if they buy then they may buy items_add=frozenset({'chicken'})
#
# and lift=4.84395061728395 which is >1 hence +ive correlation

# %%
#Simplyfying the results

def inspect(results):
    lhs = [tuple(result[2][0][0])[0] for result in results]
    rhs = [tuple(result[2][0][1])[0] for result in results]
    supports = [result[1] for result in results]
    confidence = [result[2][0][2] for result in results]
    lifts = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports,  confidence, lifts))

# %%
rindf = pd.DataFrame(inspect(results), columns=['When Purchased', 'also Purchased with it', 'support', 'confidence', 'lift'])

# %%
rindf
# Out:
#           When Purchased also Purchased with it   support  confidence  \
# 0            light cream                chicken  0.004533    0.290598
# 1   mushroom cream sauce               escalope  0.005733    0.300699
# 2                  pasta               escalope  0.005866    0.372881
# 3          fromage blanc                  honey  0.003333    0.245098
# 4          herb & pepper            ground beef  0.015998    0.323450
# ..                   ...                    ...       ...         ...
# 60     whole wheat pasta                    nan  0.007999    0.271493
# 61                 pasta                    nan  0.005066    0.322034
# 62              pancakes              olive oil  0.005066    0.201058
# 63              tomatoes              spaghetti  0.004399    0.611111
# 64      whole wheat rice               tomatoes  0.003066    0.216981
#
#         lift
# 0   4.843951
# 1   3.790833
# 2   4.700812
# 3   5.164271
# 4   3.291994
# ..       ...
# 60  4.130772
# ...

# %%
rindf.nlargest(n=10, columns='lift')


#Top 10 items which are bought together by seeing lift
# Out:
#        When Purchased also Purchased with it   support  confidence      lift
# 59  whole wheat pasta              olive oil  0.003866    0.402778  6.115863
# 50       tomato sauce            ground beef  0.003066    0.216981  5.535971
# 28      fromage blanc                  honey  0.003333    0.245098  5.178818
# 3       fromage blanc                  honey  0.003333    0.245098  5.164271
# 0         light cream                chicken  0.004533    0.290598  4.843951
# 16        light cream                    nan  0.004533    0.290598  4.843951
# 2               pasta               escalope  0.005866    0.372881  4.700812
# 26              pasta                    nan  0.005866    0.372881  4.700812
# 27        ground beef          herb & pepper  0.003200    0.230769  4.665768
# 61              pasta                    nan  0.005066    0.322034  4.515096
